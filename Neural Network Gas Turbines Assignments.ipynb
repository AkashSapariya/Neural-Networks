# %%
# Importing the necessary packages
# !pip install keras
# !pip install pandas
# !pip install numpy
# !pip install sklearn
# !pip install matplotlib
# !pip install seaborn
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import seaborn as sns
import matplotlib.pyplot as plt

#https://www.tensorflow.org/install/pip#windows

# %%
gasturbine = pd.read_csv("D:/Data Science/Assignments/Neural Networks/gas_turbines.csv")
gasturbine
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
gasturbine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gasturbine.shape
# Out:
# (15039, 11)

# %%
gasturbine.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
gasturbine.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
gasturbine.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
#
#            TEY       CDP        CO       NOX
# AT   -0.207495 -0.100705 -0.088588 -0.600006
# AP    0.146939  0.131198  0.041614  0.256744
# AH   -0.110272 -0.182010  0.165505  0.143061
# AFDP  0.717995  0.727152 -0.334207 -0.037299
# GTEP  0.977042  0.993784 -0.508259 -0.208496
# TIT   0.891587  0.887238 -0.688272 -0.231636
# TAT  -0.720356 -0.744740  0.063404  0.009888
# TEY   1.000000  0.988473 -0.541751 -0.102631
# CDP   0.988473  1.000000 -0.520783 -0.169103
# CO   -0.541751 -0.520783  1.000000  0.316743
# NOX  -0.102631 -0.169103  0.316743  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(gasturbine.corr(),annot=True,cmap="inferno")
# Out:
# <AxesSubplot:>

# %%
X=gasturbine.drop('TEY',axis=1)
X
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
Y=gasturbine['TEY']
Y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# Standardization
scaler = StandardScaler()
scaler.fit(X)
X_standardized = scaler.transform(X)
X_standardized
# Out:
# array([[-1.4397781 , -0.82664395,  1.28143632, ..., -1.35733078,
#          0.53201195,  1.3878449 ],
#        [-1.44960109, -0.74864748,  1.30456402, ..., -1.36367619,
#          0.56873344,  1.39300237],
#        [-1.43472138, -0.68625031,  1.21908576, ..., -1.36095673,
#          0.5529378 ,  1.36358566],
#        ...,
#        [-1.38626659, -1.07623263,  1.47697056, ..., -1.46792219,
#          2.69592467,  2.17006209],
#        [-1.42042259, -0.99823616,  1.44159024, ..., -1.42259784,
#          1.9246834 ,  2.391165  ],
#        [-1.43073409, -0.93583899,  1.33465179, ..., -1.37727349,
#          1.35415028,  2.32153907]])

# %%
scaled_data = pd.DataFrame(X_standardized).describe()
scaled_data
# Out:
#                   0             1             2             3             4  \
# count  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04
# mean   4.913654e-16 -1.875504e-14  2.570219e-16  1.511894e-16 -7.559468e-17
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00 -2.779497e+00 -1.806771e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01 -6.266930e-01 -5.091458e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01 -1.854065e-02 -8.075681e-02
# 75%    8.051309e-01  5.772924e-01  7.916582e-01  4.612196e-01  4.228638e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00  4.486233e+00  2.871006e+00
#
#                   5             6             7             8             9
# count  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04
# mean  -3.260021e-15  1.640405e-15  1.965462e-16  3.779734e-17  4.233302e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -5.021933e+00 -4.188141e+00 -1.992416e+00 -8.874862e-01 -3.861033e+00
# 25%   -2.540512e-01 -4.101146e-01 -4.354335e-01 -5.015202e-01 -6.578107e-01
# 50%    2.965544e-01  5.712570e-01 -7.011925e-02 -2.620452e-01 -1.518527e-01
# 75%    7.382490e-01  5.928675e-01  4.311680e-01  8.455882e-02  5.486567e-01
# max    1.028678e+00  6.627839e-01  2.700105e+00  1.895949e+01  4.937717e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(10, input_dim=10, kernel_initializer='normal', activation='relu'))
    model.add(Dense(8, kernel_initializer='normal', activation='relu'))
    model.add(Dense(8, kernel_initializer='normal', activation='relu'))
    
    adam=Adam(learning_rate=0.01)
    model.compile(loss='mean_squared_error', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasRegressor(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [50,100,200,400,800,1000]
epochs = [10,50,100]

# %%
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)

# %%
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,Y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START batch_size=50, epochs=10...................................
# [CV 1/5; 1/18] END batch_size=50, epochs=10;, score=-2352.073 total time=  19.5s
# [CV 2/5; 1/18] START batch_size=50, epochs=10...................................
# [CV 2/5; 1/18] END ...batch_size=50, epochs=10;, score=-0.476 total time=  14.0s
# [CV 3/5; 1/18] START batch_size=50, epochs=10...................................
# [CV 3/5; 1/18] END ...batch_size=50, epochs=10;, score=-0.823 total time=  11.2s
# [CV 4/5; 1/18] START batch_size=50, epochs=10...................................
# [CV 4/5; 1/18] END ...batch_size=50, epochs=10;, score=-1.732 total time=  10.6s
# [CV 5/5; 1/18] START batch_size=50, epochs=10...................................
# [CV 5/5; 1/18] END batch_size=50, epochs=10;, score=-2192.323 total time=  12.3s
# [CV 1/5; 2/18] START batch_size=50, epochs=50...................................
# [CV 1/5; 2/18] END batch_size=50, epochs=50;, score=-4701.760 total time=  48.8s
# [CV 2/5; 2/18] START batch_size=50, epochs=50...................................
# [CV 2/5; 2/18] END ...batch_size=50, epochs=50;, score=-0.467 total time=  46.0s
# [CV 3/5; 2/18] START batch_size=50, epochs=50...................................
# [CV 3/5; 2/18] END batch_size=50, epochs=50;, score=-2435.256 total time=  46.6s
# [CV 4/5; 2/18] START batch_size=50, epochs=50...................................
# [CV 4/5; 2/18] END batch_size=50, epochs=50;, score=-2314.157 total time=  43.5s
# [CV 5/5; 2/18] START batch_size=50, epochs=50...................................
# [CV 5/5; 2/18] END ...batch_size=50, epochs=50;, score=-1.325 total time=  45.0s
# [CV 1/5; 3/18] START batch_size=50, epochs=100..................................
# [CV 1/5; 3/18] END batch_size=50, epochs=100;, score=-4701.558 total time= 1.5min
# [CV 2/5; 3/18] START batch_size=50, epochs=100..................................
# [CV 2/5; 3/18] END batch_size=50, epochs=100;, score=-2122.195 total time= 1.5min
# [CV 3/5; 3/18] START batch_size=50, epochs=100..................................
# [CV 3/5; 3/18] END ..batch_size=50, epochs=100;, score=-1.648 total time= 1.5min
# [CV 4/5; 3/18] START batch_size=50, epochs=100..................................
# [CV 4/5; 3/18] END batch_size=50, epochs=100;, score=-2314.064 total time= 1.5min
# [CV 5/5; 3/18] START batch_size=50, epochs=100..................................
# [CV 5/5; 3/18] END ..batch_size=50, epochs=100;, score=-0.974 total time= 1.5min
# [CV 1/5; 4/18] START batch_size=100, epochs=10..................................
# [CV 1/5; 4/18] END batch_size=100, epochs=10;, score=-2363.650 total time=   5.9s
# [CV 2/5; 4/18] START batch_size=100, epochs=10..................................
# [CV 2/5; 4/18] END ..batch_size=100, epochs=10;, score=-1.592 total time=   9.0s
# [CV 3/5; 4/18] START batch_size=100, epochs=10..................................
# [CV 3/5; 4/18] END ..batch_size=100, epochs=10;, score=-8.277 total time=   6.7s
# [CV 4/5; 4/18] START batch_size=100, epochs=10..................................
# [CV 4/5; 4/18] END batch_size=100, epochs=10;, score=-2318.736 total time=   7.4s
# [CV 5/5; 4/18] START batch_size=100, epochs=10..................................
# [CV 5/5; 4/18] END batch_size=100, epochs=10;, score=-2196.245 total time=   6.3s
# [CV 1/5; 5/18] START batch_size=100, epochs=50..................................
# [CV 1/5; 5/18] END ..batch_size=100, epochs=50;, score=-1.338 total time=  24.0s
# [CV 2/5; 5/18] START batch_size=100, epochs=50..................................
# [CV 2/5; 5/18] END batch_size=100, epochs=50;, score=-2122.219 total time=  24.4s
# [CV 3/5; 5/18] START batch_size=100, epochs=50..................................
# [CV 3/5; 5/18] END ..batch_size=100, epochs=50;, score=-0.880 total time=  23.0s
# [CV 4/5; 5/18] START batch_size=100, epochs=50..................................
# [CV 4/5; 5/18] END ..batch_size=100, epochs=50;, score=-0.503 total time=  23.2s
# [CV 5/5; 5/18] START batch_size=100, epochs=50..................................
# [CV 5/5; 5/18] END batch_size=100, epochs=50;, score=-4382.751 total time=  27.0s
# [CV 1/5; 6/18] START batch_size=100, epochs=100.................................
# [CV 1/5; 6/18] END batch_size=100, epochs=100;, score=-2351.356 total time=  45.1s
# [CV 2/5; 6/18] START batch_size=100, epochs=100.................................
# [CV 2/5; 6/18] END .batch_size=100, epochs=100;, score=-0.410 total time=  47.1s
# [CV 3/5; 6/18] START batch_size=100, epochs=100.................................
# [CV 3/5; 6/18] END batch_size=100, epochs=100;, score=-2434.657 total time=  46.4s
# [CV 4/5; 6/18] START batch_size=100, epochs=100.................................
# [CV 4/5; 6/18] END batch_size=100, epochs=100;, score=-4627.613 total time=  46.1s
# [CV 5/5; 6/18] START batch_size=100, epochs=100.................................
# [CV 5/5; 6/18] END .batch_size=100, epochs=100;, score=-0.899 total time=  49.6s
# [CV 1/5; 7/18] START batch_size=200, epochs=10..................................
# [CV 1/5; 7/18] END .batch_size=200, epochs=10;, score=-84.814 total time=   5.7s
# [CV 2/5; 7/18] START batch_size=200, epochs=10..................................
# [CV 2/5; 7/18] END .batch_size=200, epochs=10;, score=-26.740 total time=   3.3s
# [CV 3/5; 7/18] START batch_size=200, epochs=10..................................
# [CV 3/5; 7/18] END .batch_size=200, epochs=10;, score=-34.545 total time=   6.3s
# [CV 4/5; 7/18] START batch_size=200, epochs=10..................................
# [CV 4/5; 7/18] END batch_size=200, epochs=10;, score=-2341.384 total time=   5.4s
# [CV 5/5; 7/18] START batch_size=200, epochs=10..................................
# [CV 5/5; 7/18] END batch_size=200, epochs=10;, score=-2213.725 total time=   3.6s
# [CV 1/5; 8/18] START batch_size=200, epochs=50..................................
# [CV 1/5; 8/18] END ..batch_size=200, epochs=50;, score=-1.400 total time=  14.2s
# [CV 2/5; 8/18] START batch_size=200, epochs=50..................................
# [CV 2/5; 8/18] END batch_size=200, epochs=50;, score=-2122.243 total time=  12.0s
# [CV 3/5; 8/18] START batch_size=200, epochs=50..................................
# [CV 3/5; 8/18] END ..batch_size=200, epochs=50;, score=-0.961 total time=  14.2s
# [CV 4/5; 8/18] START batch_size=200, epochs=50..................................
# [CV 4/5; 8/18] END ..batch_size=200, epochs=50;, score=-1.063 total time=  16.6s
# [CV 5/5; 8/18] START batch_size=200, epochs=50..................................
# [CV 5/5; 8/18] END ..batch_size=200, epochs=50;, score=-1.239 total time=  14.3s
# [CV 1/5; 9/18] START batch_size=200, epochs=100.................................
# [CV 1/5; 9/18] END .batch_size=200, epochs=100;, score=-0.982 total time=  28.1s
# [CV 2/5; 9/18] START batch_size=200, epochs=100.................................
# [CV 2/5; 9/18] END .batch_size=200, epochs=100;, score=-0.455 total time=  24.3s
# [CV 3/5; 9/18] START batch_size=200, epochs=100.................................
# [CV 3/5; 9/18] END .batch_size=200, epochs=100;, score=-0.671 total time=  23.7s
# [CV 4/5; 9/18] START batch_size=200, epochs=100.................................
# [CV 4/5; 9/18] END .batch_size=200, epochs=100;, score=-0.607 total time=  23.7s
# [CV 5/5; 9/18] START batch_size=200, epochs=100.................................
# [CV 5/5; 9/18] END .batch_size=200, epochs=100;, score=-1.130 total time=  23.5s
# [CV 1/5; 10/18] START batch_size=400, epochs=10.................................
# [CV 1/5; 10/18] END batch_size=400, epochs=10;, score=-234.151 total time=   4.1s
# [CV 2/5; 10/18] START batch_size=400, epochs=10.................................
# [CV 2/5; 10/18] END batch_size=400, epochs=10;, score=-155.886 total time=   3.6s
# [CV 3/5; 10/18] START batch_size=400, epochs=10.................................
# [CV 3/5; 10/18] END batch_size=400, epochs=10;, score=-190.796 total time=   2.6s
# [CV 4/5; 10/18] START batch_size=400, epochs=10.................................
# [CV 4/5; 10/18] END batch_size=400, epochs=10;, score=-102.991 total time=   2.4s
# [CV 5/5; 10/18] START batch_size=400, epochs=10.................................
# [CV 5/5; 10/18] END batch_size=400, epochs=10;, score=-106.076 total time=   3.8s
# [CV 1/5; 11/18] START batch_size=400, epochs=50.................................
# [CV 1/5; 11/18] END .batch_size=400, epochs=50;, score=-3.768 total time=   7.8s
# [CV 2/5; 11/18] START batch_size=400, epochs=50.................................
# [CV 2/5; 11/18] END .batch_size=400, epochs=50;, score=-0.845 total time=   6.6s
# [CV 3/5; 11/18] START batch_size=400, epochs=50.................................
# [CV 3/5; 11/18] END .batch_size=400, epochs=50;, score=-2.599 total time=   8.4s
# [CV 4/5; 11/18] START batch_size=400, epochs=50.................................
# [CV 4/5; 11/18] END .batch_size=400, epochs=50;, score=-2.614 total time=   7.3s
# [CV 5/5; 11/18] START batch_size=400, epochs=50.................................
# [CV 5/5; 11/18] END .batch_size=400, epochs=50;, score=-2.689 total time=   9.2s
# [CV 1/5; 12/18] START batch_size=400, epochs=100................................
# [CV 1/5; 12/18] END batch_size=400, epochs=100;, score=-1.700 total time=  12.8s
# [CV 2/5; 12/18] START batch_size=400, epochs=100................................
# [CV 2/5; 12/18] END batch_size=400, epochs=100;, score=-2122.208 total time=  14.1s
# [CV 3/5; 12/18] START batch_size=400, epochs=100................................
# [CV 3/5; 12/18] END batch_size=400, epochs=100;, score=-1.084 total time=  12.8s
# [CV 4/5; 12/18] START batch_size=400, epochs=100................................
# [CV 4/5; 12/18] END batch_size=400, epochs=100;, score=-6941.128 total time=  13.7s
# [CV 5/5; 12/18] START batch_size=400, epochs=100................................
# [CV 5/5; 12/18] END batch_size=400, epochs=100;, score=-2.070 total time=  12.3s
# [CV 1/5; 13/18] START batch_size=800, epochs=10.................................
# [CV 1/5; 13/18] END batch_size=800, epochs=10;, score=-630.429 total time=   1.9s
# [CV 2/5; 13/18] START batch_size=800, epochs=10.................................
# [CV 2/5; 13/18] END batch_size=800, epochs=10;, score=-519.345 total time=   2.3s
# [CV 3/5; 13/18] START batch_size=800, epochs=10.................................
# [CV 3/5; 13/18] END batch_size=800, epochs=10;, score=-401.942 total time=   2.3s
# [CV 4/5; 13/18] START batch_size=800, epochs=10.................................
# [CV 4/5; 13/18] END batch_size=800, epochs=10;, score=-291.251 total time=   1.7s
# [CV 5/5; 13/18] START batch_size=800, epochs=10.................................
# [CV 5/5; 13/18] END batch_size=800, epochs=10;, score=-303.728 total time=   3.6s
# [CV 1/5; 14/18] START batch_size=800, epochs=50.................................
# [CV 1/5; 14/18] END batch_size=800, epochs=50;, score=-56.296 total time=   4.8s
# [CV 2/5; 14/18] START batch_size=800, epochs=50.................................
# [CV 2/5; 14/18] END batch_size=800, epochs=50;, score=-14.822 total time=   4.3s
# [CV 3/5; 14/18] START batch_size=800, epochs=50.................................
# [CV 3/5; 14/18] END batch_size=800, epochs=50;, score=-4875.543 total time=   4.4s
# [CV 4/5; 14/18] START batch_size=800, epochs=50.................................
# [CV 4/5; 14/18] END batch_size=800, epochs=50;, score=-29.574 total time=   4.6s
# [CV 5/5; 14/18] START batch_size=800, epochs=50.................................
# [CV 5/5; 14/18] END batch_size=800, epochs=50;, score=-2204.958 total time=   4.0s
# [CV 1/5; 15/18] START batch_size=800, epochs=100................................
# [CV 1/5; 15/18] END batch_size=800, epochs=100;, score=-4.901 total time=   7.8s
# [CV 2/5; 15/18] START batch_size=800, epochs=100................................
# [CV 2/5; 15/18] END batch_size=800, epochs=100;, score=-1.217 total time=   8.4s
# [CV 3/5; 15/18] START batch_size=800, epochs=100................................
# [CV 3/5; 15/18] END batch_size=800, epochs=100;, score=-2436.598 total time=  10.6s
# [CV 4/5; 15/18] START batch_size=800, epochs=100................................
# [CV 4/5; 15/18] END batch_size=800, epochs=100;, score=-2315.423 total time=   7.2s
# [CV 5/5; 15/18] START batch_size=800, epochs=100................................
# [CV 5/5; 15/18] END batch_size=800, epochs=100;, score=-2192.171 total time=   8.0s
# [CV 1/5; 16/18] START batch_size=1000, epochs=10................................
# [CV 1/5; 16/18] END batch_size=1000, epochs=10;, score=-3038.623 total time=   1.9s
# [CV 2/5; 16/18] START batch_size=1000, epochs=10................................
# [CV 2/5; 16/18] END batch_size=1000, epochs=10;, score=-2603.154 total time=   1.7s
# [CV 3/5; 16/18] START batch_size=1000, epochs=10................................
# [CV 3/5; 16/18] END batch_size=1000, epochs=10;, score=-447.456 total time=   3.0s
# [CV 4/5; 16/18] START batch_size=1000, epochs=10................................
# [CV 4/5; 16/18] END batch_size=1000, epochs=10;, score=-551.176 total time=   2.5s
# [CV 5/5; 16/18] START batch_size=1000, epochs=10................................
# [CV 5/5; 16/18] END batch_size=1000, epochs=10;, score=-2561.701 total time=   2.4s
# [CV 1/5; 17/18] START batch_size=1000, epochs=50................................
# [CV 1/5; 17/18] END batch_size=1000, epochs=50;, score=-2404.737 total time=   5.7s
# [CV 2/5; 17/18] START batch_size=1000, epochs=50................................
# [CV 2/5; 17/18] END batch_size=1000, epochs=50;, score=-15.793 total time=   3.5s
# [CV 3/5; 17/18] START batch_size=1000, epochs=50................................
# [CV 3/5; 17/18] END batch_size=1000, epochs=50;, score=-32.299 total time=   4.7s
# [CV 4/5; 17/18] START batch_size=1000, epochs=50................................
# [CV 4/5; 17/18] END batch_size=1000, epochs=50;, score=-16.699 total time=   5.1s
# [CV 5/5; 17/18] START batch_size=1000, epochs=50................................
# [CV 5/5; 17/18] END batch_size=1000, epochs=50;, score=-23.546 total time=   4.3s
# [CV 1/5; 18/18] START batch_size=1000, epochs=100...............................
# [CV 1/5; 18/18] END batch_size=1000, epochs=100;, score=-4711.416 total time=   6.2s
# [CV 2/5; 18/18] START batch_size=1000, epochs=100...............................
# [CV 2/5; 18/18] END batch_size=1000, epochs=100;, score=-1.612 total time=   6.9s
# [CV 3/5; 18/18] START batch_size=1000, epochs=100...............................
# [CV 3/5; 18/18] END batch_size=1000, epochs=100;, score=-4870.212 total time=   6.4s
# [CV 4/5; 18/18] START batch_size=1000, epochs=100...............................
# [CV 4/5; 18/18] END batch_size=1000, epochs=100;, score=-2316.466 total time=   6.0s
# [CV 5/5; 18/18] START batch_size=1000, epochs=100...............................
# [CV 5/5; 18/18] END batch_size=1000, epochs=100;, score=-5.161 total time=   6.9s

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : -0.7687684893608093, using {'batch_size': 200, 'epochs': 100}
# -909.485437887907,1113.796438507537 with: {'batch_size': 50, 'epochs': 10}
# -1890.593195515871,1761.8533753802403 with: {'batch_size': 50, 'epochs': 50}
# -1828.0874976038933,1746.6384248443794 with: {'batch_size': 50, 'epochs': 100}
# -1377.699942946434,1122.1991632788047 with: {'batch_size': 100, 'epochs': 10}
# -1301.53843460083,1745.9849523022299 with: {'batch_size': 100, 'epochs': 50}
# -1882.9871292591095,1740.2894669728614 with: {'batch_size': 100, 'epochs': 100}
# -940.241597366333,1092.8393748675676 with: {'batch_size': 200, 'epochs': 10}
# -425.3810671925545,848.4308176061189 with: {'batch_size': 200, 'epochs': 50}
# -0.7687684893608093,0.24920277560080642 with: {'batch_size': 200, 'epochs': 100}
# -157.98018951416014,50.201739028754965 with: {'batch_size': 400, 'epochs': 10}
# -2.5032220602035524,0.9384167226319641 with: {'batch_size': 400, 'epochs': 50}
# -1813.6380432128906,2692.0856290178945 with: {'batch_size': 400, 'epochs': 100}
# -429.33900146484376,129.71917232468832 with: {'batch_size': 800, 'epochs': 10}
# -1436.2385303497315,1914.3205558071413 with: {'batch_size': 800, 'epochs': 50}
# -1390.0620158433915,1135.1187186101067 with: {'batch_size': 800, 'epochs': 100}
# -1840.422052001953,1108.1695986259035 with: {'batch_size': 1000, 'epochs': 10}
# -498.61481685638427,953.0796114587789 with: {'batch_size': 1000, 'epochs': 50}
# -2380.9732016324997,2141.834728548734 with: {'batch_size': 1000, 'epochs': 100}
